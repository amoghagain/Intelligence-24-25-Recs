# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/task2subtask1/Test/Reference/4_img_.png
# /kaggle/input/task2subtask1/Test/Reference/537_img_.png
# /kaggle/input/task2subtask1/Test/Reference/722_img_.png
# /kaggle/input/task2subtask1/Test/Reference/366_img_.png
# /kaggle/input/task2subtask1/Test/Reference/432_img_.png
# /kaggle/input/task2subtask1/Test/Reference/381_img_.png
# /kaggle/input/task2subtask1/Test/Reference/207_img_.png
# /kaggle/input/task2subtask1/Test/Reference/90_img_.png
# /kaggle/input/task2subtask1/Test/Reference/98_img_.png
# /kaggle/input/task2subtask1/Test/Reference/270_img_.png
# /kaggle/input/task2subtask1/Test/Reference/589_img_.png
# /kaggle/input/task2subtask1/Test/Reference/292_img_.png
# /kaggle/input/task2subtask1/Test/Reference/18_img_.png
# /kaggle/input/task2subtask1/Test/Reference/373_img_.png
# /kaggle/input/task2subtask1/Test/Reference/887_img_.png
# /kaggle/input/task2subtask1/Test/Reference/3650.png
# /kaggle/input/task2subtask1/Test/Reference/651.png
# /kaggle/input/task2subtask1/Test/Reference/360_img_.png
# /kaggle/input/task2subtask1/Test/Reference/647_img_.png
# /kaggle/input/task2subtask1/Test/Reference/12324.png
# /kaggle/input/task2subtask1/Test/Reference/716_img_.png
# /kaggle/input/task2subtask1/Test/Reference/50_img_.png
# /kaggle/input/task2subtask1/Test/Reference/819_img_.png
# /kaggle/input/task2subtask1/Test/Reference/463_img_.png
# /kaggle/input/task2subtask1/Test/Reference/411_img_.png
# /kaggle/input/task2subtask1/Test/Reference/904_img_.png
# /kaggle/input/task2subtask1/Test/Reference/513_img_.png
# /kaggle/input/task2subtask1/Test/Reference/628_img_.png
# /kaggle/input/task2subtask1/Test/Reference/86_img_.png
# /kaggle/input/task2subtask1/Test/Reference/605_img_.png
# /kaggle/input/task2subtask1/Test/Reference/3015.png
# /kaggle/input/task2subtask1/Test/Reference/848_img_.png
# /kaggle/input/task2subtask1/Test/Reference/351_img_.png
# /kaggle/input/task2subtask1/Test/Reference/707_img_.png
# /kaggle/input/task2subtask1/Test/Reference/137_img_.png
# /kaggle/input/task2subtask1/Test/Reference/157_img_.png
# /kaggle/input/task2subtask1/Test/Reference/769_img_.png
# /kaggle/input/task2subtask1/Test/Reference/690_img_.png
# /kaggle/input/task2subtask1/Test/Reference/794_img_.png
# /kaggle/input/task2subtask1/Test/Reference/494_img_.png
# /kaggle/input/task2subtask1/Test/Reference/141_img_.png
# /kaggle/input/task2subtask1/Test/Reference/638_img_.png
# /kaggle/input/task2subtask1/Test/Reference/15003.png
# /kaggle/input/task2subtask1/Test/Reference/15704.png
# /kaggle/input/task2subtask1/Test/Reference/59_img_.png
# /kaggle/input/task2subtask1/Test/Reference/346_img_.png
# /kaggle/input/task2subtask1/Test/Reference/838_img_.png
# /kaggle/input/task2subtask1/Test/Reference/764_img_.png
# /kaggle/input/task2subtask1/Test/Reference/231_img_.png
# /kaggle/input/task2subtask1/Test/Reference/104_img_.png
# /kaggle/input/task2subtask1/Test/Reference/911_img_.png
# /kaggle/input/task2subtask1/Test/Reference/2774.png
# /kaggle/input/task2subtask1/Test/Reference/617_img_.png
# /kaggle/input/task2subtask1/Test/Reference/850_img_.png
# /kaggle/input/task2subtask1/Test/Reference/583_img_.png
# /kaggle/input/task2subtask1/Test/Reference/82_img_.png
# /kaggle/input/task2subtask1/Test/Reference/169_img_.png
# /kaggle/input/task2subtask1/Test/Reference/723_img_.png
# /kaggle/input/task2subtask1/Test/Reference/428_img_.png
# /kaggle/input/task2subtask1/Test/Reference/595_img_.png
# /kaggle/input/task2subtask1/Test/Reference/15113.png
# /kaggle/input/task2subtask1/Test/Reference/706_img_.png
# /kaggle/input/task2subtask1/Test/Reference/851_img_.png
# /kaggle/input/task2subtask1/Test/Reference/260_img_.png
# /kaggle/input/task2subtask1/Test/Reference/594_img_.png
# /kaggle/input/task2subtask1/Test/Reference/486_img_.png
# /kaggle/input/task2subtask1/Test/Reference/9900.png
# /kaggle/input/task2subtask1/Test/Reference/159_img_.png
# /kaggle/input/task2subtask1/Test/Reference/566_img_.png
# /kaggle/input/task2subtask1/Test/Reference/402_img_.png
# /kaggle/input/task2subtask1/Test/Reference/30_img_.png
# /kaggle/input/task2subtask1/Test/Reference/151_img_.png
# /kaggle/input/task2subtask1/Test/Reference/741_img_.png
# /kaggle/input/task2subtask1/Test/Reference/598.png
# /kaggle/input/task2subtask1/Test/Reference/279_img_.png
# /kaggle/input/task2subtask1/Test/Reference/15426.png
# /kaggle/input/task2subtask1/Test/Reference/2787.png
# /kaggle/input/task2subtask1/Test/Reference/910_img_.png
# /kaggle/input/task2subtask1/Test/Reference/712_img_.png
# /kaggle/input/task2subtask1/Test/Reference/94_img_.png
# /kaggle/input/task2subtask1/Test/Reference/1225.png
# /kaggle/input/task2subtask1/Test/Reference/242_img_.png
# /kaggle/input/task2subtask1/Test/Reference/766_img_.png
# /kaggle/input/task2subtask1/Test/Reference/731_img_.png
# /kaggle/input/task2subtask1/Test/Reference/12299.png
# /kaggle/input/task2subtask1/Test/Reference/491_img_.png
# /kaggle/input/task2subtask1/Test/Reference/889_img_.png
# /kaggle/input/task2subtask1/Test/Reference/400_img_.png
# /kaggle/input/task2subtask1/Test/Reference/787_img_.png
# /kaggle/input/task2subtask1/Test/Reference/648_img_.png
# /kaggle/input/task2subtask1/Test/Reference/757_img_.png
# /kaggle/input/task2subtask1/Test/Reference/17_img_.png
# /kaggle/input/task2subtask1/Test/Reference/374_img_.png
# /kaggle/input/task2subtask1/Test/Reference/168_img_.png
# /kaggle/input/task2subtask1/Test/Reference/327_img_.png
# /kaggle/input/task2subtask1/Test/Reference/502_img_.png
# /kaggle/input/task2subtask1/Test/Reference/386_img_.png
# /kaggle/input/task2subtask1/Test/Reference/599_img_.png
# /kaggle/input/task2subtask1/Test/Reference/205_img_.png
# /kaggle/input/task2subtask1/Test/Reference/481_img_.png
# /kaggle/input/task2subtask1/Test/Reference/276_img_.png
# /kaggle/input/task2subtask1/Test/Reference/179_img_.png
# /kaggle/input/task2subtask1/Test/Reference/762_img_.png
# /kaggle/input/task2subtask1/Test/Reference/367_img_.png
# /kaggle/input/task2subtask1/Test/Reference/822_img_.png
# /kaggle/input/task2subtask1/Test/Reference/679_img_.png
# /kaggle/input/task2subtask1/Test/Reference/15045.png
# /kaggle/input/task2subtask1/Test/Reference/528_img_.png
# /kaggle/input/task2subtask1/Test/Reference/6788.png
# /kaggle/input/task2subtask1/Test/Reference/855_img_.png
# /kaggle/input/task2subtask1/Test/Reference/909_img_.png
# /kaggle/input/task2subtask1/Test/Reference/10909.png
# /kaggle/input/task2subtask1/Test/Reference/793_img_.png
# /kaggle/input/task2subtask1/Test/Reference/749_img_.png
# /kaggle/input/task2subtask1/Test/Reference/234_img_.png
# /kaggle/input/task2subtask1/Test/Reference/42_img_.png
# /kaggle/input/task2subtask1/Test/Reference/371_img_.png
# /kaggle/input/task2subtask1/Test/Reference/860_img_.png
# /kaggle/input/task2subtask1/Test/Reference/637_img_.png
# /kaggle/input/task2subtask1/Test/Reference/379_img_.png
# /kaggle/input/task2subtask1/Test/Reference/130_img_.png
# /kaggle/input/task2subtask1/Test/Reference/635_img_.png
# /kaggle/input/task2subtask1/Test/Reference/57_img_.png
# /kaggle/input/task2subtask1/Test/Reference/439_img_.png
# /kaggle/input/task2subtask1/Test/Reference/650_img_.png
# /kaggle/input/task2subtask1/Test/Reference/654_img_.png
# /kaggle/input/task2subtask1/Test/Reference/817_img_.png
# /kaggle/input/task2subtask1/Test/Reference/80_img_.png
# /kaggle/input/task2subtask1/Test/Reference/727_img_.png
# /kaggle/input/task2subtask1/Test/Reference/383_img_.png
# /kaggle/input/task2subtask1/Test/Reference/436_img_.png
# /kaggle/input/task2subtask1/Test/Reference/363_img_.png
# /kaggle/input/task2subtask1/Test/Reference/29_img_.png
# /kaggle/input/task2subtask1/Test/Reference/895_img_.png
# /kaggle/input/task2subtask1/Test/Reference/281_img_.png
# /kaggle/input/task2subtask1/Test/Reference/140_img_.png
# /kaggle/input/task2subtask1/Test/Reference/875_img_.png
# /kaggle/input/task2subtask1/Test/Reference/724_img_.png
# /kaggle/input/task2subtask1/Test/Reference/798_img_.png
# /kaggle/input/task2subtask1/Test/Reference/640_img_.png
# /kaggle/input/task2subtask1/Test/Reference/591_img_.png
# /kaggle/input/task2subtask1/Test/Reference/63_img_.png
# /kaggle/input/task2subtask1/Test/Reference/905_img_.png
# /kaggle/input/task2subtask1/Test/Reference/683_img_.png
# /kaggle/input/task2subtask1/Test/Reference/710_img_.png
# /kaggle/input/task2subtask1/Test/Reference/788_img_.png
# /kaggle/input/task2subtask1/Test/Reference/451_img_.png
# /kaggle/input/task2subtask1/Test/Reference/472_img_.png
# /kaggle/input/task2subtask1/Test/Reference/266_img_.png
# /kaggle/input/task2subtask1/Test/Reference/543_img_.png
# /kaggle/input/task2subtask1/Test/Reference/274_img_.png
# /kaggle/input/task2subtask1/Test/Reference/409_img_.png
# /kaggle/input/task2subtask1/Test/Reference/924_img_.png
# /kaggle/input/task2subtask1/Test/Reference/154_img_.png
# /kaggle/input/task2subtask1/Test/Reference/495_img_.png
# /kaggle/input/task2subtask1/Test/Reference/118_img_.png
# /kaggle/input/task2subtask1/Test/Reference/312_img_.png
# /kaggle/input/task2subtask1/Test/Reference/12290.png
# /kaggle/input/task2subtask1/Test/Reference/568_img_.png
# /kaggle/input/task2subtask1/Test/Reference/326_img_.png
# /kaggle/input/task2subtask1/Test/Reference/188_img_.png
# /kaggle/input/task2subtask1/Test/Reference/487_img_.png
# /kaggle/input/task2subtask1/Test/Reference/512_img_.png
# /kaggle/input/task2subtask1/Test/Reference/15001.png
# /kaggle/input/task2subtask1/Test/Reference/203_img_.png
# /kaggle/input/task2subtask1/Test/Reference/687_img_.png
# /kaggle/input/task2subtask1/Test/Reference/15418.png
# /kaggle/input/task2subtask1/Test/Reference/345_img_.png
# /kaggle/input/task2subtask1/Test/Reference/202_img_.png
# /kaggle/input/task2subtask1/Test/Reference/515_img_.png
# /kaggle/input/task2subtask1/Test/Reference/704_img_.png
# /kaggle/input/task2subtask1/Test/Reference/338_img_.png
# /kaggle/input/task2subtask1/Test/Reference/12445.png
# /kaggle/input/task2subtask1/Test/Reference/359_img_.png
# /kaggle/input/task2subtask1/Test/Reference/450_img_.png
# /kaggle/input/task2subtask1/Test/Reference/149_img_.png
# /kaggle/input/task2subtask1/Test/Reference/465_img_.png
# /kaggle/input/task2subtask1/Test/Reference/574_img_.png
# /kaggle/input/task2subtask1/Test/Reference/275_img_.png
# /kaggle/input/task2subtask1/Test/Reference/906_img_.png
# /kaggle/input/task2subtask1/Test/Reference/552_img_.png
# /kaggle/input/task2subtask1/Test/Reference/316_img_.png
# /kaggle/input/task2subtask1/Test/Reference/880_img_.png
# /kaggle/input/task2subtask1/Test/Reference/658_img_.png
# /kaggle/input/task2subtask1/Test/Reference/263_img_.png
# /kaggle/input/task2subtask1/Test/Reference/482_img_.png
# /kaggle/input/task2subtask1/Test/Reference/116_img_.png
# /kaggle/input/task2subtask1/Test/Reference/37_img_.png
# /kaggle/input/task2subtask1/Test/Reference/641_img_.png
# /kaggle/input/task2subtask1/Test/Reference/837.png
# /kaggle/input/task2subtask1/Test/Raw/4_img_.png
# /kaggle/input/task2subtask1/Test/Raw/537_img_.png
# /kaggle/input/task2subtask1/Test/Raw/722_img_.png
# /kaggle/input/task2subtask1/Test/Raw/366_img_.png
# /kaggle/input/task2subtask1/Test/Raw/432_img_.png
# /kaggle/input/task2subtask1/Test/Raw/381_img_.png
# /kaggle/input/task2subtask1/Test/Raw/207_img_.png
# /kaggle/input/task2subtask1/Test/Raw/90_img_.png
# /kaggle/input/task2subtask1/Test/Raw/98_img_.png
# /kaggle/input/task2subtask1/Test/Raw/270_img_.png
# /kaggle/input/task2subtask1/Test/Raw/589_img_.png
# /kaggle/input/task2subtask1/Test/Raw/292_img_.png
# /kaggle/input/task2subtask1/Test/Raw/18_img_.png
# /kaggle/input/task2subtask1/Test/Raw/373_img_.png
# /kaggle/input/task2subtask1/Test/Raw/887_img_.png
# /kaggle/input/task2subtask1/Test/Raw/3650.png
# /kaggle/input/task2subtask1/Test/Raw/651.png
# /kaggle/input/task2subtask1/Test/Raw/360_img_.png
# /kaggle/input/task2subtask1/Test/Raw/647_img_.png
# /kaggle/input/task2subtask1/Test/Raw/12324.png
# /kaggle/input/task2subtask1/Test/Raw/716_img_.png
# /kaggle/input/task2subtask1/Test/Raw/50_img_.png
# /kaggle/input/task2subtask1/Test/Raw/819_img_.png
# /kaggle/input/task2subtask1/Test/Raw/463_img_.png
# /kaggle/input/task2subtask1/Test/Raw/411_img_.png
# /kaggle/input/task2subtask1/Test/Raw/904_img_.png
# /kaggle/input/task2subtask1/Test/Raw/513_img_.png
# /kaggle/input/task2subtask1/Test/Raw/628_img_.png
# /kaggle/input/task2subtask1/Test/Raw/86_img_.png
# /kaggle/input/task2subtask1/Test/Raw/605_img_.png
# /kaggle/input/task2subtask1/Test/Raw/3015.png
# /kaggle/input/task2subtask1/Test/Raw/848_img_.png
# /kaggle/input/task2subtask1/Test/Raw/351_img_.png
# /kaggle/input/task2subtask1/Test/Raw/707_img_.png
# /kaggle/input/task2subtask1/Test/Raw/137_img_.png
# /kaggle/input/task2subtask1/Test/Raw/157_img_.png
# /kaggle/input/task2subtask1/Test/Raw/769_img_.png
# /kaggle/input/task2subtask1/Test/Raw/690_img_.png
# /kaggle/input/task2subtask1/Test/Raw/794_img_.png
# /kaggle/input/task2subtask1/Test/Raw/494_img_.png
# /kaggle/input/task2subtask1/Test/Raw/141_img_.png
# /kaggle/input/task2subtask1/Test/Raw/638_img_.png
# /kaggle/input/task2subtask1/Test/Raw/15003.png
# /kaggle/input/task2subtask1/Test/Raw/15704.png
# /kaggle/input/task2subtask1/Test/Raw/59_img_.png
# /kaggle/input/task2subtask1/Test/Raw/346_img_.png
# /kaggle/input/task2subtask1/Test/Raw/838_img_.png
# /kaggle/input/task2subtask1/Test/Raw/764_img_.png
# /kaggle/input/task2subtask1/Test/Raw/231_img_.png
# /kaggle/input/task2subtask1/Test/Raw/104_img_.png
# /kaggle/input/task2subtask1/Test/Raw/911_img_.png
# /kaggle/input/task2subtask1/Test/Raw/2774.png
# /kaggle/input/task2subtask1/Test/Raw/617_img_.png
# /kaggle/input/task2subtask1/Test/Raw/850_img_.png
# /kaggle/input/task2subtask1/Test/Raw/583_img_.png
# /kaggle/input/task2subtask1/Test/Raw/82_img_.png
# /kaggle/input/task2subtask1/Test/Raw/169_img_.png
# /kaggle/input/task2subtask1/Test/Raw/723_img_.png
# /kaggle/input/task2subtask1/Test/Raw/428_img_.png
# /kaggle/input/task2subtask1/Test/Raw/595_img_.png
# /kaggle/input/task2subtask1/Test/Raw/15113.png
# /kaggle/input/task2subtask1/Test/Raw/706_img_.png
# /kaggle/input/task2subtask1/Test/Raw/851_img_.png
# /kaggle/input/task2subtask1/Test/Raw/260_img_.png
# /kaggle/input/task2subtask1/Test/Raw/594_img_.png
# /kaggle/input/task2subtask1/Test/Raw/486_img_.png
# /kaggle/input/task2subtask1/Test/Raw/9900.png
# /kaggle/input/task2subtask1/Test/Raw/159_img_.png
# /kaggle/input/task2subtask1/Test/Raw/566_img_.png
# /kaggle/input/task2subtask1/Test/Raw/402_img_.png
# /kaggle/input/task2subtask1/Test/Raw/30_img_.png
# /kaggle/input/task2subtask1/Test/Raw/151_img_.png
# /kaggle/input/task2subtask1/Test/Raw/741_img_.png
# /kaggle/input/task2subtask1/Test/Raw/598.png
# /kaggle/input/task2subtask1/Test/Raw/279_img_.png
# /kaggle/input/task2subtask1/Test/Raw/15426.png
# /kaggle/input/task2subtask1/Test/Raw/2787.png
# /kaggle/input/task2subtask1/Test/Raw/910_img_.png
# /kaggle/input/task2subtask1/Test/Raw/712_img_.png
# /kaggle/input/task2subtask1/Test/Raw/94_img_.png
# /kaggle/input/task2subtask1/Test/Raw/1225.png
# /kaggle/input/task2subtask1/Test/Raw/242_img_.png
# /kaggle/input/task2subtask1/Test/Raw/766_img_.png
# /kaggle/input/task2subtask1/Test/Raw/731_img_.png
# /kaggle/input/task2subtask1/Test/Raw/12299.png
# /kaggle/input/task2subtask1/Test/Raw/491_img_.png
# /kaggle/input/task2subtask1/Test/Raw/889_img_.png
# /kaggle/input/task2subtask1/Test/Raw/400_img_.png
# /kaggle/input/task2subtask1/Test/Raw/787_img_.png
# /kaggle/input/task2subtask1/Test/Raw/648_img_.png
# /kaggle/input/task2subtask1/Test/Raw/757_img_.png
# /kaggle/input/task2subtask1/Test/Raw/17_img_.png
# /kaggle/input/task2subtask1/Test/Raw/374_img_.png
# /kaggle/input/task2subtask1/Test/Raw/168_img_.png
# /kaggle/input/task2subtask1/Test/Raw/327_img_.png
# /kaggle/input/task2subtask1/Test/Raw/502_img_.png
# /kaggle/input/task2subtask1/Test/Raw/386_img_.png
# /kaggle/input/task2subtask1/Test/Raw/599_img_.png
# /kaggle/input/task2subtask1/Test/Raw/205_img_.png
# /kaggle/input/task2subtask1/Test/Raw/481_img_.png
# /kaggle/input/task2subtask1/Test/Raw/276_img_.png
# /kaggle/input/task2subtask1/Test/Raw/179_img_.png
# /kaggle/input/task2subtask1/Test/Raw/762_img_.png
# /kaggle/input/task2subtask1/Test/Raw/367_img_.png
# /kaggle/input/task2subtask1/Test/Raw/822_img_.png
# /kaggle/input/task2subtask1/Test/Raw/679_img_.png
# /kaggle/input/task2subtask1/Test/Raw/15045.png
# /kaggle/input/task2subtask1/Test/Raw/528_img_.png
# /kaggle/input/task2subtask1/Test/Raw/6788.png
# /kaggle/input/task2subtask1/Test/Raw/855_img_.png
# /kaggle/input/task2subtask1/Test/Raw/909_img_.png
# /kaggle/input/task2subtask1/Test/Raw/10909.png
# /kaggle/input/task2subtask1/Test/Raw/793_img_.png
# /kaggle/input/task2subtask1/Test/Raw/749_img_.png
# /kaggle/input/task2subtask1/Test/Raw/234_img_.png
# /kaggle/input/task2subtask1/Test/Raw/42_img_.png
# /kaggle/input/task2subtask1/Test/Raw/371_img_.png
# /kaggle/input/task2subtask1/Test/Raw/860_img_.png
# /kaggle/input/task2subtask1/Test/Raw/637_img_.png
# /kaggle/input/task2subtask1/Test/Raw/379_img_.png
# /kaggle/input/task2subtask1/Test/Raw/130_img_.png
# /kaggle/input/task2subtask1/Test/Raw/635_img_.png
# /kaggle/input/task2subtask1/Test/Raw/57_img_.png
# /kaggle/input/task2subtask1/Test/Raw/439_img_.png
# /kaggle/input/task2subtask1/Test/Raw/650_img_.png
# /kaggle/input/task2subtask1/Test/Raw/654_img_.png
# /kaggle/input/task2subtask1/Test/Raw/817_img_.png
# /kaggle/input/task2subtask1/Test/Raw/80_img_.png
# /kaggle/input/task2subtask1/Test/Raw/727_img_.png
# /kaggle/input/task2subtask1/Test/Raw/383_img_.png
# /kaggle/input/task2subtask1/Test/Raw/436_img_.png
# /kaggle/input/task2subtask1/Test/Raw/363_img_.png
# /kaggle/input/task2subtask1/Test/Raw/29_img_.png
# /kaggle/input/task2subtask1/Test/Raw/895_img_.png
# /kaggle/input/task2subtask1/Test/Raw/281_img_.png
# /kaggle/input/task2subtask1/Test/Raw/140_img_.png
# /kaggle/input/task2subtask1/Test/Raw/875_img_.png
# /kaggle/input/task2subtask1/Test/Raw/724_img_.png
# /kaggle/input/task2subtask1/Test/Raw/798_img_.png
# /kaggle/input/task2subtask1/Test/Raw/640_img_.png
# /kaggle/input/task2subtask1/Test/Raw/591_img_.png
# /kaggle/input/task2subtask1/Test/Raw/63_img_.png
# /kaggle/input/task2subtask1/Test/Raw/905_img_.png
# /kaggle/input/task2subtask1/Test/Raw/683_img_.png
# /kaggle/input/task2subtask1/Test/Raw/710_img_.png
# /kaggle/input/task2subtask1/Test/Raw/788_img_.png
# /kaggle/input/task2subtask1/Test/Raw/451_img_.png
# /kaggle/input/task2subtask1/Test/Raw/472_img_.png
# /kaggle/input/task2subtask1/Test/Raw/266_img_.png
# /kaggle/input/task2subtask1/Test/Raw/543_img_.png
# /kaggle/input/task2subtask1/Test/Raw/274_img_.png
# /kaggle/input/task2subtask1/Test/Raw/409_img_.png
# /kaggle/input/task2subtask1/Test/Raw/924_img_.png
# /kaggle/input/task2subtask1/Test/Raw/154_img_.png
# /kaggle/input/task2subtask1/Test/Raw/495_img_.png
# /kaggle/input/task2subtask1/Test/Raw/118_img_.png
# /kaggle/input/task2subtask1/Test/Raw/312_img_.png
# /kaggle/input/task2subtask1/Test/Raw/12290.png
# /kaggle/input/task2subtask1/Test/Raw/568_img_.png
# /kaggle/input/task2subtask1/Test/Raw/326_img_.png
# /kaggle/input/task2subtask1/Test/Raw/188_img_.png
# /kaggle/input/task2subtask1/Test/Raw/487_img_.png
# /kaggle/input/task2subtask1/Test/Raw/512_img_.png
# /kaggle/input/task2subtask1/Test/Raw/15001.png
# /kaggle/input/task2subtask1/Test/Raw/203_img_.png
# /kaggle/input/task2subtask1/Test/Raw/687_img_.png
# /kaggle/input/task2subtask1/Test/Raw/15418.png
# /kaggle/input/task2subtask1/Test/Raw/345_img_.png
# /kaggle/input/task2subtask1/Test/Raw/202_img_.png
# /kaggle/input/task2subtask1/Test/Raw/515_img_.png
# /kaggle/input/task2subtask1/Test/Raw/704_img_.png
# /kaggle/input/task2subtask1/Test/Raw/338_img_.png
# /kaggle/input/task2subtask1/Test/Raw/12445.png
# /kaggle/input/task2subtask1/Test/Raw/359_img_.png
# /kaggle/input/task2subtask1/Test/Raw/450_img_.png
# /kaggle/input/task2subtask1/Test/Raw/149_img_.png
# /kaggle/input/task2subtask1/Test/Raw/465_img_.png
# /kaggle/input/task2subtask1/Test/Raw/574_img_.png
# /kaggle/input/task2subtask1/Test/Raw/275_img_.png
# /kaggle/input/task2subtask1/Test/Raw/906_img_.png
# /kaggle/input/task2subtask1/Test/Raw/552_img_.png
# /kaggle/input/task2subtask1/Test/Raw/316_img_.png
# /kaggle/input/task2subtask1/Test/Raw/880_img_.png
# /kaggle/input/task2subtask1/Test/Raw/658_img_.png
# /kaggle/input/task2subtask1/Test/Raw/263_img_.png
# /kaggle/input/task2subtask1/Test/Raw/482_img_.png
# /kaggle/input/task2subtask1/Test/Raw/116_img_.png
# /kaggle/input/task2subtask1/Test/Raw/37_img_.png
# /kaggle/input/task2subtask1/Test/Raw/641_img_.png
# /kaggle/input/task2subtask1/Test/Raw/837.png
# /kaggle/input/task2subtask1/Train/Reference/271_img_.png
# /kaggle/input/task2subtask1/Train/Reference/859_img_.png
# /kaggle/input/task2subtask1/Train/Reference/425_img_.png
# /kaggle/input/task2subtask1/Train/Reference/896_img_.png
# /kaggle/input/task2subtask1/Train/Reference/758_img_.png
# /kaggle/input/task2subtask1/Train/Reference/587_img_.png
# /kaggle/input/task2subtask1/Train/Reference/849_img_.png
# /kaggle/input/task2subtask1/Train/Reference/511_img_.png
# /kaggle/input/task2subtask1/Train/Reference/499_img_.png
# /kaggle/input/task2subtask1/Train/Reference/97_img_.png
# /kaggle/input/task2subtask1/Train/Reference/540_img_.png
# /kaggle/input/task2subtask1/Train/Reference/415_img_.png
# /kaggle/input/task2subtask1/Train/Reference/507_img_.png
# /kaggle/input/task2subtask1/Train/Reference/222_img_.png
# /kaggle/input/task2subtask1/Train/Reference/526_img_.png
# /kaggle/input/task2subtask1/Train/Reference/376_img_.png
# /kaggle/input/task2subtask1/Train/Reference/61_img_.png
# /kaggle/input/task2subtask1/Train/Reference/627_img_.png
# /kaggle/input/task2subtask1/Train/Reference/201_img_.png
# /kaggle/input/task2subtask1/Train/Reference/393_img_.png
# /kaggle/input/task2subtask1/Train/Reference/619_img_.png
# /kaggle/input/task2subtask1/Train/Reference/117_img_.png
# /kaggle/input/task2subtask1/Train/Reference/779_img_.png
# /kaggle/input/task2subtask1/Train/Reference/12348.png
# /kaggle/input/task2subtask1/Train/Reference/384_img_.png
# /kaggle/input/task2subtask1/Train/Reference/3728.png
# /kaggle/input/task2subtask1/Train/Reference/626_img_.png
# /kaggle/input/task2subtask1/Train/Reference/45_img_.png
# /kaggle/input/task2subtask1/Train/Reference/901_img_.png
# /kaggle/input/task2subtask1/Train/Reference/245_img_.png
# /kaggle/input/task2subtask1/Train/Reference/306_img_.png
# /kaggle/input/task2subtask1/Train/Reference/55_img_.png
# /kaggle/input/task2subtask1/Train/Reference/828_img_.png
# /kaggle/input/task2subtask1/Train/Reference/158_img_.png
# /kaggle/input/task2subtask1/Train/Reference/462_img_.png
# /kaggle/input/task2subtask1/Train/Reference/928_img_.png
# /kaggle/input/task2subtask1/Train/Reference/781_img_.png
# /kaggle/input/task2subtask1/Train/Reference/413_img_.png
# /kaggle/input/task2subtask1/Train/Reference/254_img_.png
# /kaggle/input/task2subtask1/Train/Reference/600_img_.png
# /kaggle/input/task2subtask1/Train/Reference/777_img_.png
# /kaggle/input/task2subtask1/Train/Reference/454_img_.png
# /kaggle/input/task2subtask1/Train/Reference/492_img_.png
# /kaggle/input/task2subtask1/Train/Reference/35.png
# /kaggle/input/task2subtask1/Train/Reference/186_img_.png
# /kaggle/input/task2subtask1/Train/Reference/446_img_.png
# /kaggle/input/task2subtask1/Train/Reference/142_img_.png
# /kaggle/input/task2subtask1/Train/Reference/866_img_.png
# /kaggle/input/task2subtask1/Train/Reference/133_img_.png
# /kaggle/input/task2subtask1/Train/Reference/403_img_.png
# /kaggle/input/task2subtask1/Train/Reference/14_img_.png
# /kaggle/input/task2subtask1/Train/Reference/4070.png
# /kaggle/input/task2subtask1/Train/Reference/74_img_.png
# /kaggle/input/task2subtask1/Train/Reference/148_img_.png
# /kaggle/input/task2subtask1/Train/Reference/364_img_.png
# /kaggle/input/task2subtask1/Train/Reference/143_img_.png
# /kaggle/input/task2subtask1/Train/Reference/509_img_.png
# /kaggle/input/task2subtask1/Train/Reference/213_img_.png
# /kaggle/input/task2subtask1/Train/Reference/441_img_.png
# /kaggle/input/task2subtask1/Train/Reference/620_img_.png
# /kaggle/input/task2subtask1/Train/Reference/614_img_.png
# /kaggle/input/task2subtask1/Train/Reference/410_img_.png
# /kaggle/input/task2subtask1/Train/Reference/530_img_.png
# /kaggle/input/task2subtask1/Train/Reference/557_img_.png
# /kaggle/input/task2subtask1/Train/Reference/745_img_.png
# /kaggle/input/task2subtask1/Train/Reference/770_img_.png
# /kaggle/input/task2subtask1/Train/Reference/8288.png
# /kaggle/input/task2subtask1/Train/Reference/636_img_.png
# /kaggle/input/task2subtask1/Train/Reference/26_img_.png
# /kaggle/input/task2subtask1/Train/Reference/913_img_.png
# /kaggle/input/task2subtask1/Train/Reference/581_img_.png
# /kaggle/input/task2subtask1/Train/Reference/65_img_.png
# /kaggle/input/task2subtask1/Train/Reference/334_img_.png
# /kaggle/input/task2subtask1/Train/Reference/670_img_.png
# /kaggle/input/task2subtask1/Train/Reference/361_img_.png
# /kaggle/input/task2subtask1/Train/Reference/24_img_.png
# /kaggle/input/task2subtask1/Train/Reference/9554.png
# /kaggle/input/task2subtask1/Train/Reference/112_img_.png
# /kaggle/input/task2subtask1/Train/Reference/448_img_.png
# /kaggle/input/task2subtask1/Train/Reference/874_img_.png
# /kaggle/input/task2subtask1/Train/Reference/293_img_.png
# /kaggle/input/task2subtask1/Train/Reference/747_img_.png
# /kaggle/input/task2subtask1/Train/Reference/892_img_.png
# /kaggle/input/task2subtask1/Train/Reference/330_img_.png
# /kaggle/input/task2subtask1/Train/Reference/200_img_.png
# /kaggle/input/task2subtask1/Train/Reference/592_img_.png
# /kaggle/input/task2subtask1/Train/Reference/28_img_.png
# /kaggle/input/task2subtask1/Train/Reference/535_img_.png
# /kaggle/input/task2subtask1/Train/Reference/872_img_.png
# /kaggle/input/task2subtask1/Train/Reference/782_img_.png
# /kaggle/input/task2subtask1/Train/Reference/319_img_.png
# /kaggle/input/task2subtask1/Train/Reference/542_img_.png
# /kaggle/input/task2subtask1/Train/Reference/484_img_.png
# /kaggle/input/task2subtask1/Train/Reference/332_img_.png
# /kaggle/input/task2subtask1/Train/Reference/443_img_.png
# /kaggle/input/task2subtask1/Train/Reference/871_img_.png
# /kaggle/input/task2subtask1/Train/Reference/464_img_.png
# /kaggle/input/task2subtask1/Train/Reference/25_img_.png
# /kaggle/input/task2subtask1/Train/Reference/225_img_.png
# /kaggle/input/task2subtask1/Train/Reference/470_img_.png
# /kaggle/input/task2subtask1/Train/Reference/751_img_.png
# /kaggle/input/task2subtask1/Train/Reference/438_img_.png
# /kaggle/input/task2subtask1/Train/Reference/227_img_.png
# /kaggle/input/task2subtask1/Train/Reference/738_img_.png
# /kaggle/input/task2subtask1/Train/Reference/675_img_.png
# /kaggle/input/task2subtask1/Train/Reference/51_img_.png
# /kaggle/input/task2subtask1/Train/Reference/31.png
# /kaggle/input/task2subtask1/Train/Reference/273_img_.png
# /kaggle/input/task2subtask1/Train/Reference/510_img_.png
# /kaggle/input/task2subtask1/Train/Reference/280_img_.png
# /kaggle/input/task2subtask1/Train/Reference/146_img_.png
# /kaggle/input/task2subtask1/Train/Reference/863_img_.png
# /kaggle/input/task2subtask1/Train/Reference/180_img_.png
# /kaggle/input/task2subtask1/Train/Reference/806_img_.png
# /kaggle/input/task2subtask1/Train/Reference/214_img_.png
# /kaggle/input/task2subtask1/Train/Reference/606_img_.png
# /kaggle/input/task2subtask1/Train/Reference/921_img_.png
# /kaggle/input/task2subtask1/Train/Reference/567_img_.png
# /kaggle/input/task2subtask1/Train/Reference/652_img_.png
# /kaggle/input/task2subtask1/Train/Reference/564_img_.png
# /kaggle/input/task2subtask1/Train/Reference/808_img_.png
# /kaggle/input/task2subtask1/Train/Reference/355_img_.png
# /kaggle/input/task2subtask1/Train/Reference/632_img_.png
# /kaggle/input/task2subtask1/Train/Reference/4.png
# /kaggle/input/task2subtask1/Train/Reference/549_img_.png
# /kaggle/input/task2subtask1/Train/Reference/733_img_.png
# /kaggle/input/task2subtask1/Train/Reference/102_img_.png
# /kaggle/input/task2subtask1/Train/Reference/573_img_.png
# /kaggle/input/task2subtask1/Train/Reference/224_img_.png
# /kaggle/input/task2subtask1/Train/Reference/5830.png
# /kaggle/input/task2subtask1/Train/Reference/518_img_.png
# /kaggle/input/task2subtask1/Train/Reference/621_img_.png
# /kaggle/input/task2subtask1/Train/Reference/478_img_.png
# /kaggle/input/task2subtask1/Train/Reference/290_img_.png
# /kaggle/input/task2subtask1/Train/Reference/746_img_.png
# /kaggle/input/task2subtask1/Train/Reference/498_img_.png
# /kaggle/input/task2subtask1/Train/Reference/49_img_.png
# /kaggle/input/task2subtask1/Train/Reference/212_img_.png
# /kaggle/input/task2subtask1/Train/Reference/489_img_.png
# /kaggle/input/task2subtask1/Train/Reference/288_img_.png
# /kaggle/input/task2subtask1/Train/Reference/433_img_.png
# /kaggle/input/task2subtask1/Train/Reference/461_img_.png
# /kaggle/input/task2subtask1/Train/Reference/668_img_.png
# /kaggle/input/task2subtask1/Train/Reference/395_img_.png
# /kaggle/input/task2subtask1/Train/Reference/7916.png
# /kaggle/input/task2subtask1/Train/Reference/101_img_.png
# /kaggle/input/task2subtask1/Train/Reference/570_img_.png
# /kaggle/input/task2subtask1/Train/Reference/10139.png
# /kaggle/input/task2subtask1/Train/Reference/508_img_.png
# /kaggle/input/task2subtask1/Train/Reference/847_img_.png
# /kaggle/input/task2subtask1/Train/Reference/786_img_.png
# /kaggle/input/task2subtask1/Train/Reference/810_img_.png
# /kaggle/input/task2subtask1/Train/Reference/686_img_.png
# /kaggle/input/task2subtask1/Train/Reference/320_img_.png
# /kaggle/input/task2subtask1/Train/Reference/265_img_.png
# /kaggle/input/task2subtask1/Train/Reference/323_img_.png
# /kaggle/input/task2subtask1/Train/Reference/503_img_.png
# /kaggle/input/task2subtask1/Train/Reference/3330.png
# /kaggle/input/task2subtask1/Train/Reference/387_img_.png
# /kaggle/input/task2subtask1/Train/Reference/767_img_.png
# /kaggle/input/task2subtask1/Train/Reference/729_img_.png
# /kaggle/input/task2subtask1/Train/Reference/843_img_.png
# /kaggle/input/task2subtask1/Train/Reference/541_img_.png
# /kaggle/input/task2subtask1/Train/Reference/682_img_.png
# /kaggle/input/task2subtask1/Train/Reference/64_img_.png
# /kaggle/input/task2subtask1/Train/Reference/685_img_.png
# /kaggle/input/task2subtask1/Train/Reference/814_img_.png
# /kaggle/input/task2subtask1/Train/Reference/642_img_.png
# /kaggle/input/task2subtask1/Train/Reference/496_img_.png
# /kaggle/input/task2subtask1/Train/Reference/908_img_.png
# /kaggle/input/task2subtask1/Train/Reference/160_img_.png
# /kaggle/input/task2subtask1/Train/Reference/700_img_.png
# /kaggle/input/task2subtask1/Train/Reference/519_img_.png
# /kaggle/input/task2subtask1/Train/Reference/247_img_.png
# /kaggle/input/task2subtask1/Train/Reference/12433.png
# /kaggle/input/task2subtask1/Train/Reference/744_img_.png
# /kaggle/input/task2subtask1/Train/Reference/174_img_.png
# /kaggle/input/task2subtask1/Train/Reference/248_img_.png
# /kaggle/input/task2subtask1/Train/Reference/796_img_.png
# /kaggle/input/task2subtask1/Train/Reference/258_img_.png
# /kaggle/input/task2subtask1/Train/Reference/812_img_.png
# /kaggle/input/task2subtask1/Train/Reference/435_img_.png
# /kaggle/input/task2subtask1/Train/Reference/460_img_.png
# /kaggle/input/task2subtask1/Train/Reference/2546.png
# /kaggle/input/task2subtask1/Train/Reference/8262.png
# /kaggle/input/task2subtask1/Train/Reference/5554.png
# /kaggle/input/task2subtask1/Train/Reference/672_img_.png
# /kaggle/input/task2subtask1/Train/Reference/406_img_.png
# /kaggle/input/task2subtask1/Train/Reference/466_img_.png
# /kaggle/input/task2subtask1/Train/Reference/348_img_.png
# /kaggle/input/task2subtask1/Train/Reference/877_img_.png
# /kaggle/input/task2subtask1/Train/Reference/401_img_.png
# /kaggle/input/task2subtask1/Train/Reference/666_img_.png
# /kaggle/input/task2subtask1/Train/Reference/858_img_.png
# /kaggle/input/task2subtask1/Train/Reference/215_img_.png
# /kaggle/input/task2subtask1/Train/Reference/625_img_.png
# /kaggle/input/task2subtask1/Train/Reference/251_img_.png
# /kaggle/input/task2subtask1/Train/Reference/16_img_.png
# /kaggle/input/task2subtask1/Train/Reference/416_img_.png
# /kaggle/input/task2subtask1/Train/Reference/556_img_.png
# /kaggle/input/task2subtask1/Train/Reference/217_img_.png
# /kaggle/input/task2subtask1/Train/Reference/699_img_.png
# /kaggle/input/task2subtask1/Train/Reference/784_img_.png
# /kaggle/input/task2subtask1/Train/Reference/837_img_.png
# /kaggle/input/task2subtask1/Train/Reference/697_img_.png
# /kaggle/input/task2subtask1/Train/Reference/171_img_.png
# /kaggle/input/task2subtask1/Train/Reference/190_img_.png
# /kaggle/input/task2subtask1/Train/Reference/726_img_.png
# /kaggle/input/task2subtask1/Train/Reference/593_img_.png
# /kaggle/input/task2subtask1/Train/Reference/375_img_.png
# /kaggle/input/task2subtask1/Train/Reference/663_img_.png
# /kaggle/input/task2subtask1/Train/Reference/835_img_.png
# /kaggle/input/task2subtask1/Train/Reference/15136.png
# /kaggle/input/task2subtask1/Train/Reference/2629.png
# /kaggle/input/task2subtask1/Train/Reference/325_img_.png
# /kaggle/input/task2subtask1/Train/Reference/429_img_.png
# /kaggle/input/task2subtask1/Train/Reference/586_img_.png
# /kaggle/input/task2subtask1/Train/Reference/577_img_.png
# /kaggle/input/task2subtask1/Train/Reference/834_img_.png
# /kaggle/input/task2subtask1/Train/Reference/799_img_.png
# /kaggle/input/task2subtask1/Train/Reference/407_img_.png
# /kaggle/input/task2subtask1/Train/Reference/773_img_.png
# /kaggle/input/task2subtask1/Train/Reference/469_img_.png
# /kaggle/input/task2subtask1/Train/Reference/547_img_.png
# /kaggle/input/task2subtask1/Train/Reference/7027.png
# /kaggle/input/task2subtask1/Train/Reference/483_img_.png
# /kaggle/input/task2subtask1/Train/Reference/9947.png
# /kaggle/input/task2subtask1/Train/Reference/653_img_.png
# /kaggle/input/task2subtask1/Train/Reference/211_img_.png
# /kaggle/input/task2subtask1/Train/Reference/185_img_.png
# /kaggle/input/task2subtask1/Train/Reference/867_img_.png
# /kaggle/input/task2subtask1/Train/Reference/278_img_.png
# /kaggle/input/task2subtask1/Train/Reference/2_img_.png
# /kaggle/input/task2subtask1/Train/Reference/760_img_.png
# /kaggle/input/task2subtask1/Train/Reference/878_img_.png
# /kaggle/input/task2subtask1/Train/Reference/660_img_.png
# /kaggle/input/task2subtask1/Train/Reference/193_img_.png
# /kaggle/input/task2subtask1/Train/Reference/804_img_.png
# /kaggle/input/task2subtask1/Train/Reference/15094.png
# /kaggle/input/task2subtask1/Train/Reference/304_img_.png
# /kaggle/input/task2subtask1/Train/Reference/337_img_.png
# /kaggle/input/task2subtask1/Train/Reference/915_img_.png
# /kaggle/input/task2subtask1/Train/Reference/287_img_.png
# /kaggle/input/task2subtask1/Train/Reference/736_img_.png
# /kaggle/input/task2subtask1/Train/Reference/601_img_.png
# /kaggle/input/task2subtask1/Train/Reference/572_img_.png
# /kaggle/input/task2subtask1/Train/Reference/277_img_.png
# /kaggle/input/task2subtask1/Train/Reference/43_img_.png
# /kaggle/input/task2subtask1/Train/Reference/362_img_.png
# /kaggle/input/task2subtask1/Train/Reference/111_img_.png
# /kaggle/input/task2subtask1/Train/Reference/7643.png
# /kaggle/input/task2subtask1/Train/Reference/854_img_.png
# /kaggle/input/task2subtask1/Train/Reference/192_img_.png
# /kaggle/input/task2subtask1/Train/Reference/221_img_.png
# /kaggle/input/task2subtask1/Train/Reference/920_img_.png
# /kaggle/input/task2subtask1/Train/Reference/6820.png
# /kaggle/input/task2subtask1/Train/Reference/861_img_.png
# /kaggle/input/task2subtask1/Train/Reference/922_img_.png
# /kaggle/input/task2subtask1/Train/Reference/790_img_.png
# /kaggle/input/task2subtask1/Train/Reference/785_img_.png
# /kaggle/input/task2subtask1/Train/Reference/268_img_.png
# /kaggle/input/task2subtask1/Train/Reference/1407.png
# /kaggle/input/task2subtask1/Train/Reference/539_img_.png
# /kaggle/input/task2subtask1/Train/Reference/649_img_.png
# /kaggle/input/task2subtask1/Train/Reference/1573.png
# /kaggle/input/task2subtask1/Train/Reference/87_img_.png
# /kaggle/input/task2subtask1/Train/Reference/95_img_.png
# /kaggle/input/task2subtask1/Train/Reference/756_img_.png
# /kaggle/input/task2subtask1/Train/Reference/170_img_.png
# /kaggle/input/task2subtask1/Train/Reference/531_img_.png
# /kaggle/input/task2subtask1/Train/Reference/382_img_.png
# /kaggle/input/task2subtask1/Train/Reference/829_img_.png
# /kaggle/input/task2subtask1/Train/Reference/893_img_.png
# /kaggle/input/task2subtask1/Train/Reference/493_img_.png
# /kaggle/input/task2subtask1/Train/Reference/198_img_.png
# /kaggle/input/task2subtask1/Train/Reference/768_img_.png
# /kaggle/input/task2subtask1/Train/Reference/516_img_.png
# /kaggle/input/task2subtask1/Train/Reference/544_img_.png
# /kaggle/input/task2subtask1/Train/Reference/631_img_.png
# /kaggle/input/task2subtask1/Train/Reference/907_img_.png
# /kaggle/input/task2subtask1/Train/Reference/420_img_.png
# /kaggle/input/task2subtask1/Train/Reference/655_img_.png
# /kaggle/input/task2subtask1/Train/Reference/815_img_.png
# /kaggle/input/task2subtask1/Train/Reference/77_img_.png
# /kaggle/input/task2subtask1/Train/Reference/929_img_.png
# /kaggle/input/task2subtask1/Train/Reference/58_img_.png
# /kaggle/input/task2subtask1/Train/Reference/754_img_.png
# /kaggle/input/task2subtask1/Train/Reference/506_img_.png
# /kaggle/input/task2subtask1/Train/Reference/20.png
# /kaggle/input/task2subtask1/Train/Reference/735_img_.png
# /kaggle/input/task2subtask1/Train/Reference/752_img_.png
# /kaggle/input/task2subtask1/Train/Reference/6_img_.png
# /kaggle/input/task2subtask1/Train/Reference/656_img_.png
# /kaggle/input/task2subtask1/Train/Reference/152_img_.png
# /kaggle/input/task2subtask1/Train/Reference/613_img_.png
# /kaggle/input/task2subtask1/Train/Reference/129_img_.png
# /kaggle/input/task2subtask1/Train/Reference/678_img_.png
# /kaggle/input/task2subtask1/Train/Reference/596_img_.png
# /kaggle/input/task2subtask1/Train/Reference/841_img_.png
# /kaggle/input/task2subtask1/Train/Reference/41_img_.png
# /kaggle/input/task2subtask1/Train/Reference/676_img_.png
# /kaggle/input/task2subtask1/Train/Reference/177_img_.png
# /kaggle/input/task2subtask1/Train/Reference/730_img_.png
# /kaggle/input/task2subtask1/Train/Reference/295_img_.png
# /kaggle/input/task2subtask1/Train/Reference/199_img_.png
# /kaggle/input/task2subtask1/Train/Reference/6082.png
# /kaggle/input/task2subtask1/Train/Reference/623_img_.png
# /kaggle/input/task2subtask1/Train/Reference/772_img_.png
# /kaggle/input/task2subtask1/Train/Reference/611_img_.png
# /kaggle/input/task2subtask1/Train/Reference/194_img_.png
# /kaggle/input/task2subtask1/Train/Reference/925_img_.png
# /kaggle/input/task2subtask1/Train/Reference/189_img_.png
# /kaggle/input/task2subtask1/Train/Reference/67_img_.png
# /kaggle/input/task2subtask1/Train/Reference/827_img_.png
# /kaggle/input/task2subtask1/Train/Reference/6872.png
# /kaggle/input/task2subtask1/Train/Reference/501_img_.png
# /kaggle/input/task2subtask1/Train/Reference/709_img_.png
# /kaggle/input/task2subtask1/Train/Reference/131_img_.png
# /kaggle/input/task2subtask1/Train/Reference/630_img_.png
# /kaggle/input/task2subtask1/Train/Reference/584_img_.png
# /kaggle/input/task2subtask1/Train/Reference/341_img_.png
# /kaggle/input/task2subtask1/Train/Reference/590_img_.png
# /kaggle/input/task2subtask1/Train/Reference/750_img_.png
# /kaggle/input/task2subtask1/Train/Reference/356_img_.png
# /kaggle/input/task2subtask1/Train/Reference/353_img_.png
# /kaggle/input/task2subtask1/Train/Reference/46_img_.png
# /kaggle/input/task2subtask1/Train/Reference/490_img_.png
# /kaggle/input/task2subtask1/Train/Reference/317_img_.png
# /kaggle/input/task2subtask1/Train/Reference/298_img_.png
# /kaggle/input/task2subtask1/Train/Reference/719_img_.png
# /kaggle/input/task2subtask1/Train/Reference/480_img_.png
# /kaggle/input/task2subtask1/Train/Reference/527_img_.png
# /kaggle/input/task2subtask1/Train/Reference/923_img_.png
# /kaggle/input/task2subtask1/Train/Reference/380_img_.png
# /kaggle/input/task2subtask1/Train/Reference/917_img_.png
# /kaggle/input/task2subtask1/Train/Reference/307_img_.png
# /kaggle/input/task2subtask1/Train/Reference/108_img_.png
# /kaggle/input/task2subtask1/Train/Reference/135_img_.png
# /kaggle/input/task2subtask1/Train/Reference/802_img_.png
# /kaggle/input/task2subtask1/Train/Reference/385_img_.png
# /kaggle/input/task2subtask1/Train/Reference/708_img_.png
# /kaggle/input/task2subtask1/Train/Reference/53_img_.png
# /kaggle/input/task2subtask1/Train/Reference/183_img_.png
# /kaggle/input/task2subtask1/Train/Reference/48_img_.png
# /kaggle/input/task2subtask1/Train/Reference/737_img_.png
# /kaggle/input/task2subtask1/Train/Reference/299_img_.png
# /kaggle/input/task2subtask1/Train/Reference/912_img_.png
# /kaggle/input/task2subtask1/Train/Reference/209_img_.png
# /kaggle/input/task2subtask1/Train/Reference/246_img_.png
# /kaggle/input/task2subtask1/Train/Reference/471_img_.png
# /kaggle/input/task2subtask1/Train/Reference/918_img_.png
# /kaggle/input/task2subtask1/Train/Reference/115_img_.png
# /kaggle/input/task2subtask1/Train/Reference/763_img_.png
# /kaggle/input/task2subtask1/Train/Reference/881_img_.png
# /kaggle/input/task2subtask1/Train/Reference/121_img_.png
# /kaggle/input/task2subtask1/Train/Reference/10151.png
# /kaggle/input/task2subtask1/Train/Reference/919_img_.png
# /kaggle/input/task2subtask1/Train/Reference/122_img_.png
# /kaggle/input/task2subtask1/Train/Reference/424_img_.png
# /kaggle/input/task2subtask1/Train/Reference/914_img_.png
# /kaggle/input/task2subtask1/Train/Reference/302_img_.png
# /kaggle/input/task2subtask1/Train/Reference/485_img_.png
# /kaggle/input/task2subtask1/Train/Reference/11374.png
# /kaggle/input/task2subtask1/Train/Reference/449_img_.png
# /kaggle/input/task2subtask1/Train/Reference/62_img_.png
# /kaggle/input/task2subtask1/Train/Reference/229_img_.png
# /kaggle/input/task2subtask1/Train/Reference/9896.png
# /kaggle/input/task2subtask1/Train/Reference/206_img_.png
# /kaggle/input/task2subtask1/Train/Reference/890.png
# /kaggle/input/task2subtask1/Train/Reference/633_img_.png
# /kaggle/input/task2subtask1/Train/Reference/166_img_.png
# /kaggle/input/task2subtask1/Train/Reference/78_img_.png
# /kaggle/input/task2subtask1/Train/Reference/92_img_.png
# /kaggle/input/task2subtask1/Train/Reference/76_img_.png
# /kaggle/input/task2subtask1/Train/Reference/311_img_.png
# /kaggle/input/task2subtask1/Train/Reference/846_img_.png
# /kaggle/input/task2subtask1/Train/Reference/615_img_.png
# /kaggle/input/task2subtask1/Train/Reference/524_img_.png
# /kaggle/input/task2subtask1/Train/Reference/551_img_.png
# /kaggle/input/task2subtask1/Train/Reference/703_img_.png
# /kaggle/input/task2subtask1/Train/Reference/852_img_.png
# /kaggle/input/task2subtask1/Train/Reference/651_img_.png
# /kaggle/input/task2subtask1/Train/Reference/272_img_.png
# /kaggle/input/task2subtask1/Train/Reference/241_img_.png
# /kaggle/input/task2subtask1/Train/Reference/73_img_.png
# /kaggle/input/task2subtask1/Train/Reference/578_img_.png
# /kaggle/input/task2subtask1/Train/Reference/576_img_.png
# /kaggle/input/task2subtask1/Train/Reference/868_img_.png
# /kaggle/input/task2subtask1/Train/Reference/187_img_.png
# /kaggle/input/task2subtask1/Train/Reference/164_img_.png
# /kaggle/input/task2subtask1/Train/Reference/99_img_.png
# /kaggle/input/task2subtask1/Train/Reference/372_img_.png
# /kaggle/input/task2subtask1/Train/Reference/597_img_.png
# /kaggle/input/task2subtask1/Train/Reference/285_img_.png
# /kaggle/input/task2subtask1/Train/Reference/588_img_.png
# /kaggle/input/task2subtask1/Train/Reference/216_img_.png
# /kaggle/input/task2subtask1/Train/Reference/680_img_.png
# /kaggle/input/task2subtask1/Train/Reference/163_img_.png
# /kaggle/input/task2subtask1/Train/Reference/219_img_.png
# /kaggle/input/task2subtask1/Train/Reference/844_img_.png
# /kaggle/input/task2subtask1/Train/Reference/10_img_.png
# /kaggle/input/task2subtask1/Train/Reference/608_img_.png
# /kaggle/input/task2subtask1/Train/Reference/479_img_.png
# /kaggle/input/task2subtask1/Train/Reference/8056.png
# /kaggle/input/task2subtask1/Train/Reference/72_img_.png
# /kaggle/input/task2subtask1/Train/Reference/262_img_.png
# /kaggle/input/task2subtask1/Train/Reference/3001.png
# /kaggle/input/task2subtask1/Train/Reference/255_img_.png
# /kaggle/input/task2subtask1/Train/Reference/421_img_.png
# /kaggle/input/task2subtask1/Train/Reference/172_img_.png
# /kaggle/input/task2subtask1/Train/Reference/445_img_.png
# /kaggle/input/task2subtask1/Train/Reference/296_img_.png
# /kaggle/input/task2subtask1/Train/Reference/582_img_.png
# /kaggle/input/task2subtask1/Train/Reference/792_img_.png
# /kaggle/input/task2subtask1/Train/Reference/440_img_.png
# /kaggle/input/task2subtask1/Train/Reference/452_img_.png
# /kaggle/input/task2subtask1/Train/Reference/89_img_.png
# /kaggle/input/task2subtask1/Train/Reference/422_img_.png
# /kaggle/input/task2subtask1/Train/Reference/800_img_.png
# /kaggle/input/task2subtask1/Train/Reference/370_img_.png
# /kaggle/input/task2subtask1/Train/Reference/144_img_.png
# /kaggle/input/task2subtask1/Train/Reference/1660.png
# /kaggle/input/task2subtask1/Train/Reference/257_img_.png
# /kaggle/input/task2subtask1/Train/Reference/314_img_.png
# /kaggle/input/task2subtask1/Train/Reference/758.png
# /kaggle/input/task2subtask1/Train/Reference/39_img_.png
# /kaggle/input/task2subtask1/Train/Reference/580_img_.png
# /kaggle/input/task2subtask1/Train/Reference/412_img_.png
# /kaggle/input/task2subtask1/Train/Reference/559.png
# /kaggle/input/task2subtask1/Train/Reference/458_img_.png
# /kaggle/input/task2subtask1/Train/Reference/405_img_.png
# /kaggle/input/task2subtask1/Train/Reference/476_img_.png
# /kaggle/input/task2subtask1/Train/Reference/96_img_.png
# /kaggle/input/task2subtask1/Train/Reference/879_img_.png
# /kaggle/input/task2subtask1/Train/Reference/681_img_.png
# /kaggle/input/task2subtask1/Train/Reference/340_img_.png
# /kaggle/input/task2subtask1/Train/Reference/602_img_.png
# /kaggle/input/task2subtask1/Train/Reference/569_img_.png
# /kaggle/input/task2subtask1/Train/Reference/534_img_.png
# /kaggle/input/task2subtask1/Train/Reference/107_img_.png
# /kaggle/input/task2subtask1/Train/Reference/505_img_.png
# /kaggle/input/task2subtask1/Train/Reference/208_img_.png
# /kaggle/input/task2subtask1/Train/Reference/563.png
# /kaggle/input/task2subtask1/Train/Reference/305_img_.png
# /kaggle/input/task2subtask1/Train/Reference/765_img_.png
# /kaggle/input/task2subtask1/Train/Reference/604_img_.png
# /kaggle/input/task2subtask1/Train/Reference/842_img_.png
# /kaggle/input/task2subtask1/Train/Reference/691_img_.png
# /kaggle/input/task2subtask1/Train/Reference/240_img_.png
# /kaggle/input/task2subtask1/Train/Reference/916_img_.png
# /kaggle/input/task2subtask1/Train/Reference/423_img_.png
# /kaggle/input/task2subtask1/Train/Reference/563_img_.png
# /kaggle/input/task2subtask1/Train/Reference/616_img_.png
# /kaggle/input/task2subtask1/Train/Reference/609_img_.png
# /kaggle/input/task2subtask1/Train/Reference/23_img_.png
# /kaggle/input/task2subtask1/Train/Reference/56_img_.png
# /kaggle/input/task2subtask1/Train/Reference/294_img_.png
# /kaggle/input/task2subtask1/Train/Reference/236_img_.png
# /kaggle/input/task2subtask1/Train/Reference/756.png
# /kaggle/input/task2subtask1/Train/Reference/575_img_.png
# /kaggle/input/task2subtask1/Train/Reference/820_img_.png
# /kaggle/input/task2subtask1/Train/Reference/8_img_.png
# /kaggle/input/task2subtask1/Train/Reference/12336.png
# /kaggle/input/task2subtask1/Train/Reference/197_img_.png
# /kaggle/input/task2subtask1/Train/Reference/44_img_.png
# /kaggle/input/task2subtask1/Train/Reference/2882.png
# /kaggle/input/task2subtask1/Train/Reference/109_img_.png
# /kaggle/input/task2subtask1/Train/Reference/417_img_.png
# /kaggle/input/task2subtask1/Train/Reference/696_img_.png
# /kaggle/input/task2subtask1/Train/Reference/377_img_.png
# /kaggle/input/task2subtask1/Train/Reference/701_img_.png
# /kaggle/input/task2subtask1/Train/Reference/579_img_.png
# /kaggle/input/task2subtask1/Train/Reference/532_img_.png
# /kaggle/input/task2subtask1/Train/Reference/336_img_.png
# /kaggle/input/task2subtask1/Train/Reference/714_img_.png
# /kaggle/input/task2subtask1/Train/Reference/176_img_.png
# /kaggle/input/task2subtask1/Train/Reference/70_img_.png
# /kaggle/input/task2subtask1/Train/Reference/196_img_.png
# /kaggle/input/task2subtask1/Train/Reference/688_img_.png
# /kaggle/input/task2subtask1/Train/Reference/533_img_.png
# /kaggle/input/task2subtask1/Train/Reference/9557.png
# /kaggle/input/task2subtask1/Train/Reference/301_img_.png
# /kaggle/input/task2subtask1/Train/Reference/220_img_.png
# /kaggle/input/task2subtask1/Train/Reference/473_img_.png
# /kaggle/input/task2subtask1/Train/Reference/392_img_.png
# /kaggle/input/task2subtask1/Train/Reference/230_img_.png
# /kaggle/input/task2subtask1/Train/Reference/1742.png
# /kaggle/input/task2subtask1/Train/Reference/3202.png
# /kaggle/input/task2subtask1/Train/Reference/139_img_.png
# /kaggle/input/task2subtask1/Train/Reference/232_img_.png
# /kaggle/input/task2subtask1/Train/Reference/315_img_.png
# /kaggle/input/task2subtask1/Train/Reference/161_img_.png
# /kaggle/input/task2subtask1/Train/Reference/238_img_.png
# /kaggle/input/task2subtask1/Train/Reference/803_img_.png
# /kaggle/input/task2subtask1/Train/Reference/674_img_.png
# /kaggle/input/task2subtask1/Train/Reference/153_img_.png
# ...
# /kaggle/input/task2subtask1/Train/Raw/241_img_.png
# /kaggle/input/task2subtask1/Train/Raw/73_img_.png
# /kaggle/input/task2subtask1/Train/Raw/578_img_.png
# /kaggle/input/task2subtask1/Train/Raw/576_img_.png
# /kaggle/input/task2subtask1/Train/Raw/868_img_.png
# /kaggle/input/task2subtask1/Train/Raw/187_img_.png
# /kaggle/input/task2subtask1/Train/Raw/164_img_.png
# /kaggle/input/task2subtask1/Train/Raw/99_img_.png
# /kaggle/input/task2subtask1/Train/Raw/372_img_.png
# /kaggle/input/task2subtask1/Train/Raw/597_img_.png
# /kaggle/input/task2subtask1/Train/Raw/285_img_.png
# /kaggle/input/task2subtask1/Train/Raw/588_img_.png
# /kaggle/input/task2subtask1/Train/Raw/216_img_.png
# /kaggle/input/task2subtask1/Train/Raw/680_img_.png
# /kaggle/input/task2subtask1/Train/Raw/163_img_.png
# /kaggle/input/task2subtask1/Train/Raw/219_img_.png
# /kaggle/input/task2subtask1/Train/Raw/844_img_.png
# /kaggle/input/task2subtask1/Train/Raw/10_img_.png
# /kaggle/input/task2subtask1/Train/Raw/608_img_.png
# /kaggle/input/task2subtask1/Train/Raw/479_img_.png
# /kaggle/input/task2subtask1/Train/Raw/8056.png
# /kaggle/input/task2subtask1/Train/Raw/72_img_.png
# /kaggle/input/task2subtask1/Train/Raw/262_img_.png
# /kaggle/input/task2subtask1/Train/Raw/3001.png
# /kaggle/input/task2subtask1/Train/Raw/255_img_.png
# /kaggle/input/task2subtask1/Train/Raw/421_img_.png
# /kaggle/input/task2subtask1/Train/Raw/172_img_.png
# /kaggle/input/task2subtask1/Train/Raw/445_img_.png
# /kaggle/input/task2subtask1/Train/Raw/296_img_.png
# /kaggle/input/task2subtask1/Train/Raw/582_img_.png
# /kaggle/input/task2subtask1/Train/Raw/792_img_.png
# /kaggle/input/task2subtask1/Train/Raw/440_img_.png
# /kaggle/input/task2subtask1/Train/Raw/452_img_.png
# /kaggle/input/task2subtask1/Train/Raw/89_img_.png
# /kaggle/input/task2subtask1/Train/Raw/422_img_.png
# /kaggle/input/task2subtask1/Train/Raw/800_img_.png
# /kaggle/input/task2subtask1/Train/Raw/370_img_.png
# /kaggle/input/task2subtask1/Train/Raw/144_img_.png
# /kaggle/input/task2subtask1/Train/Raw/1660.png
# /kaggle/input/task2subtask1/Train/Raw/257_img_.png
# /kaggle/input/task2subtask1/Train/Raw/314_img_.png
# /kaggle/input/task2subtask1/Train/Raw/758.png
# /kaggle/input/task2subtask1/Train/Raw/39_img_.png
# /kaggle/input/task2subtask1/Train/Raw/580_img_.png
# /kaggle/input/task2subtask1/Train/Raw/412_img_.png
# /kaggle/input/task2subtask1/Train/Raw/559.png
# /kaggle/input/task2subtask1/Train/Raw/458_img_.png
# /kaggle/input/task2subtask1/Train/Raw/405_img_.png
# /kaggle/input/task2subtask1/Train/Raw/476_img_.png
# /kaggle/input/task2subtask1/Train/Raw/96_img_.png
# /kaggle/input/task2subtask1/Train/Raw/879_img_.png
# /kaggle/input/task2subtask1/Train/Raw/681_img_.png
# /kaggle/input/task2subtask1/Train/Raw/340_img_.png
# /kaggle/input/task2subtask1/Train/Raw/602_img_.png
# /kaggle/input/task2subtask1/Train/Raw/569_img_.png
# /kaggle/input/task2subtask1/Train/Raw/534_img_.png
# /kaggle/input/task2subtask1/Train/Raw/107_img_.png
# /kaggle/input/task2subtask1/Train/Raw/505_img_.png
# /kaggle/input/task2subtask1/Train/Raw/208_img_.png
# /kaggle/input/task2subtask1/Train/Raw/563.png
# /kaggle/input/task2subtask1/Train/Raw/305_img_.png
# /kaggle/input/task2subtask1/Train/Raw/765_img_.png
# /kaggle/input/task2subtask1/Train/Raw/604_img_.png
# /kaggle/input/task2subtask1/Train/Raw/842_img_.png
# /kaggle/input/task2subtask1/Train/Raw/691_img_.png
# /kaggle/input/task2subtask1/Train/Raw/240_img_.png
# /kaggle/input/task2subtask1/Train/Raw/916_img_.png
# /kaggle/input/task2subtask1/Train/Raw/423_img_.png
# /kaggle/input/task2subtask1/Train/Raw/563_img_.png
# /kaggle/input/task2subtask1/Train/Raw/616_img_.png
# /kaggle/input/task2subtask1/Train/Raw/609_img_.png
# /kaggle/input/task2subtask1/Train/Raw/23_img_.png
# /kaggle/input/task2subtask1/Train/Raw/56_img_.png
# /kaggle/input/task2subtask1/Train/Raw/294_img_.png
# /kaggle/input/task2subtask1/Train/Raw/236_img_.png
# /kaggle/input/task2subtask1/Train/Raw/756.png
# /kaggle/input/task2subtask1/Train/Raw/575_img_.png
# /kaggle/input/task2subtask1/Train/Raw/820_img_.png
# /kaggle/input/task2subtask1/Train/Raw/8_img_.png
# /kaggle/input/task2subtask1/Train/Raw/12336.png
# /kaggle/input/task2subtask1/Train/Raw/197_img_.png
# /kaggle/input/task2subtask1/Train/Raw/44_img_.png
# /kaggle/input/task2subtask1/Train/Raw/2882.png
# /kaggle/input/task2subtask1/Train/Raw/109_img_.png
# /kaggle/input/task2subtask1/Train/Raw/417_img_.png
# /kaggle/input/task2subtask1/Train/Raw/696_img_.png
# /kaggle/input/task2subtask1/Train/Raw/377_img_.png
# /kaggle/input/task2subtask1/Train/Raw/701_img_.png
# /kaggle/input/task2subtask1/Train/Raw/579_img_.png
# /kaggle/input/task2subtask1/Train/Raw/532_img_.png
# /kaggle/input/task2subtask1/Train/Raw/336_img_.png
# /kaggle/input/task2subtask1/Train/Raw/714_img_.png
# /kaggle/input/task2subtask1/Train/Raw/176_img_.png
# /kaggle/input/task2subtask1/Train/Raw/70_img_.png
# /kaggle/input/task2subtask1/Train/Raw/196_img_.png
# /kaggle/input/task2subtask1/Train/Raw/688_img_.png
# /kaggle/input/task2subtask1/Train/Raw/533_img_.png
# /kaggle/input/task2subtask1/Train/Raw/9557.png
# /kaggle/input/task2subtask1/Train/Raw/301_img_.png
# /kaggle/input/task2subtask1/Train/Raw/220_img_.png
# /kaggle/input/task2subtask1/Train/Raw/473_img_.png
# /kaggle/input/task2subtask1/Train/Raw/392_img_.png
# /kaggle/input/task2subtask1/Train/Raw/230_img_.png
# /kaggle/input/task2subtask1/Train/Raw/1742.png
# /kaggle/input/task2subtask1/Train/Raw/3202.png
# /kaggle/input/task2subtask1/Train/Raw/139_img_.png
# /kaggle/input/task2subtask1/Train/Raw/232_img_.png
# /kaggle/input/task2subtask1/Train/Raw/315_img_.png
# /kaggle/input/task2subtask1/Train/Raw/161_img_.png
# /kaggle/input/task2subtask1/Train/Raw/238_img_.png
# /kaggle/input/task2subtask1/Train/Raw/803_img_.png
# /kaggle/input/task2subtask1/Train/Raw/674_img_.png
# /kaggle/input/task2subtask1/Train/Raw/153_img_.png
# /kaggle/input/task2subtask1/Train/Raw/639_img_.png
# /kaggle/input/task2subtask1/Train/Raw/457_img_.png
# /kaggle/input/task2subtask1/Train/Raw/155_img_.png
# /kaggle/input/task2subtask1/Train/Raw/300_img_.png
# /kaggle/input/task2subtask1/Train/Raw/210_img_.png
# /kaggle/input/task2subtask1/Train/Raw/19_img_.png
# /kaggle/input/task2subtask1/Train/Raw/890_img_.png
# /kaggle/input/task2subtask1/Train/Raw/195_img_.png
# /kaggle/input/task2subtask1/Train/Raw/394_img_.png
# /kaggle/input/task2subtask1/Train/Raw/253_img_.png
# /kaggle/input/task2subtask1/Train/Raw/873_img_.png
# /kaggle/input/task2subtask1/Train/Raw/123_img_.png
# /kaggle/input/task2subtask1/Train/Raw/567.png
# /kaggle/input/task2subtask1/Train/Raw/328_img_.png
# /kaggle/input/task2subtask1/Train/Raw/629_img_.png
# /kaggle/input/task2subtask1/Train/Raw/598_img_.png
# /kaggle/input/task2subtask1/Train/Raw/797_img_.png
# /kaggle/input/task2subtask1/Train/Raw/389_img_.png
# /kaggle/input/task2subtask1/Train/Raw/252_img_.png
# /kaggle/input/task2subtask1/Train/Raw/347_img_.png
# /kaggle/input/task2subtask1/Train/Raw/10945.png
# /kaggle/input/task2subtask1/Train/Raw/5818.png
# /kaggle/input/task2subtask1/Train/Raw/734_img_.png
# /kaggle/input/task2subtask1/Train/Raw/378_img_.png
# /kaggle/input/task2subtask1/Train/Raw/2977.png
# /kaggle/input/task2subtask1/Train/Raw/7654.png
# /kaggle/input/task2subtask1/Train/Raw/705_img_.png
# /kaggle/input/task2subtask1/Train/Raw/244_img_.png
# /kaggle/input/task2subtask1/Train/Raw/284_img_.png
# /kaggle/input/task2subtask1/Train/Raw/684_img_.png
# /kaggle/input/task2subtask1/Train/Raw/162_img_.png
# /kaggle/input/task2subtask1/Train/Raw/711_img_.png
# /kaggle/input/task2subtask1/Train/Raw/558_img_.png
# /kaggle/input/task2subtask1/Train/Raw/165_img_.png
# /kaggle/input/task2subtask1/Train/Raw/9_img_.png
# /kaggle/input/task2subtask1/Train/Raw/718_img_.png
# /kaggle/input/task2subtask1/Train/Raw/9547.png
# /kaggle/input/task2subtask1/Train/Raw/809_img_.png
# /kaggle/input/task2subtask1/Train/Raw/662_img_.png
# /kaggle/input/task2subtask1/Train/Raw/15_img_.png
# /kaggle/input/task2subtask1/Train/Raw/150_img_.png
# /kaggle/input/task2subtask1/Train/Raw/105_img_.png
# /kaggle/input/task2subtask1/Train/Raw/453_img_.png
# /kaggle/input/task2subtask1/Train/Raw/538_img_.png
# /kaggle/input/task2subtask1/Train/Raw/100_img_.png
# /kaggle/input/task2subtask1/Train/Raw/791_img_.png
# /kaggle/input/task2subtask1/Train/Raw/517_img_.png
# /kaggle/input/task2subtask1/Train/Raw/661_img_.png
# /kaggle/input/task2subtask1/Train/Raw/841.png
# /kaggle/input/task2subtask1/Train/Raw/862_img_.png
# /kaggle/input/task2subtask1/Train/Raw/753_img_.png
# /kaggle/input/task2subtask1/Train/Raw/891_img_.png
# /kaggle/input/task2subtask1/Train/Raw/243_img_.png
# /kaggle/input/task2subtask1/Train/Raw/404_img_.png
# /kaggle/input/task2subtask1/Train/Raw/715_img_.png
# /kaggle/input/task2subtask1/Train/Raw/743_img_.png
# /kaggle/input/task2subtask1/Train/Raw/350_img_.png
# /kaggle/input/task2subtask1/Train/Raw/554_img_.png
# /kaggle/input/task2subtask1/Train/Raw/468_img_.png
# /kaggle/input/task2subtask1/Train/Raw/645_img_.png
# /kaggle/input/task2subtask1/Train/Raw/497_img_.png
# /kaggle/input/task2subtask1/Train/Raw/3_img_.png
# /kaggle/input/task2subtask1/Train/Raw/408_img_.png
# /kaggle/input/task2subtask1/Train/Raw/603_img_.png
# /kaggle/input/task2subtask1/Train/Raw/795_img_.png
# /kaggle/input/task2subtask1/Train/Raw/732_img_.png
# /kaggle/input/task2subtask1/Train/Raw/318_img_.png
# /kaggle/input/task2subtask1/Train/Raw/79_img_.png
# /kaggle/input/task2subtask1/Train/Raw/467_img_.png
# /kaggle/input/task2subtask1/Train/Raw/3196.png
# /kaggle/input/task2subtask1/Train/Raw/3947.png
# /kaggle/input/task2subtask1/Train/Raw/437_img_.png
# /kaggle/input/task2subtask1/Train/Raw/322_img_.png
# /kaggle/input/task2subtask1/Train/Raw/173_img_.png
# /kaggle/input/task2subtask1/Train/Raw/6062.png
# /kaggle/input/task2subtask1/Train/Raw/22_img_.png
# /kaggle/input/task2subtask1/Train/Raw/138_img_.png
# /kaggle/input/task2subtask1/Train/Raw/865_img_.png
# /kaggle/input/task2subtask1/Train/Raw/145_img_.png
# /kaggle/input/task2subtask1/Train/Raw/324_img_.png
# /kaggle/input/task2subtask1/Train/Raw/343_img_.png
# /kaggle/input/task2subtask1/Train/Raw/8046.png
# /kaggle/input/task2subtask1/Train/Raw/659_img_.png
# /kaggle/input/task2subtask1/Train/Raw/748_img_.png
# /kaggle/input/task2subtask1/Train/Raw/11_img_.png
# /kaggle/input/task2subtask1/Train/Raw/418_img_.png
# /kaggle/input/task2subtask1/Train/Raw/585_img_.png
# /kaggle/input/task2subtask1/Train/Raw/488_img_.png
# /kaggle/input/task2subtask1/Train/Raw/191_img_.png
# /kaggle/input/task2subtask1/Train/Raw/673_img_.png
# /kaggle/input/task2subtask1/Train/Raw/52_img_.png
# /kaggle/input/task2subtask1/Train/Raw/561_img_.png
# /kaggle/input/task2subtask1/Train/Raw/832_img_.png
# /kaggle/input/task2subtask1/Train/Raw/442_img_.png
# /kaggle/input/task2subtask1/Train/Raw/689_img_.png
# /kaggle/input/task2subtask1/Train/Raw/365_img_.png
# /kaggle/input/task2subtask1/Train/Raw/831_img_.png
# /kaggle/input/task2subtask1/Train/Raw/775_img_.png
# /kaggle/input/task2subtask1/Train/Raw/759_img_.png
# /kaggle/input/task2subtask1/Train/Raw/713_img_.png
# /kaggle/input/task2subtask1/Train/Raw/856_img_.png
# /kaggle/input/task2subtask1/Train/Raw/226_img_.png
# /kaggle/input/task2subtask1/Train/Raw/2701.png
# /kaggle/input/task2subtask1/Train/Raw/12422.png
# /kaggle/input/task2subtask1/Train/Raw/477_img_.png
# /kaggle/input/task2subtask1/Train/Raw/1539.png
# /kaggle/input/task2subtask1/Train/Raw/618_img_.png
# /kaggle/input/task2subtask1/Train/Raw/342_img_.png
# /kaggle/input/task2subtask1/Train/Raw/562_img_.png
# /kaggle/input/task2subtask1/Train/Raw/233_img_.png
# /kaggle/input/task2subtask1/Train/Raw/9907.png
# /kaggle/input/task2subtask1/Train/Raw/259_img_.png
# /kaggle/input/task2subtask1/Train/Raw/182_img_.png
# /kaggle/input/task2subtask1/Train/Raw/184_img_.png
# /kaggle/input/task2subtask1/Train/Raw/545_img_.png
# /kaggle/input/task2subtask1/Train/Raw/11398.png
# /kaggle/input/task2subtask1/Train/Raw/228_img_.png
# /kaggle/input/task2subtask1/Train/Raw/926_img_.png
# /kaggle/input/task2subtask1/Train/Raw/823_img_.png
# /kaggle/input/task2subtask1/Train/Raw/27_img_.png
# /kaggle/input/task2subtask1/Train/Raw/789_img_.png
# /kaggle/input/task2subtask1/Train/Raw/125_img_.png
# /kaggle/input/task2subtask1/Train/Raw/267_img_.png
# /kaggle/input/task2subtask1/Train/Raw/223_img_.png
# /kaggle/input/task2subtask1/Train/Raw/282_img_.png
# /kaggle/input/task2subtask1/Train/Raw/622_img_.png
# /kaggle/input/task2subtask1/Train/Raw/677_img_.png
# /kaggle/input/task2subtask1/Train/Raw/106_img_.png
# /kaggle/input/task2subtask1/Train/Raw/546_img_.png
# /kaggle/input/task2subtask1/Train/Raw/702_img_.png
# /kaggle/input/task2subtask1/Train/Raw/927_img_.png
# /kaggle/input/task2subtask1/Train/Raw/692_img_.png
# /kaggle/input/task2subtask1/Train/Raw/876_img_.png
# /kaggle/input/task2subtask1/Train/Raw/369_img_.png
# /kaggle/input/task2subtask1/Train/Raw/1491.png
# /kaggle/input/task2subtask1/Train/Raw/13_img_.png
# /kaggle/input/task2subtask1/Train/Raw/634_img_.png
# /kaggle/input/task2subtask1/Train/Raw/536_img_.png
# /kaggle/input/task2subtask1/Train/Raw/459_img_.png
# /kaggle/input/task2subtask1/Train/Raw/261_img_.png
# /kaggle/input/task2subtask1/Train/Raw/539.png
# /kaggle/input/task2subtask1/Train/Raw/11052.png
# /kaggle/input/task2subtask1/Train/Raw/818_img_.png
# /kaggle/input/task2subtask1/Train/Raw/610_img_.png
# /kaggle/input/task2subtask1/Train/Raw/156_img_.png
# /kaggle/input/task2subtask1/Train/Raw/695_img_.png
# /kaggle/input/task2subtask1/Train/Raw/204_img_.png
# /kaggle/input/task2subtask1/Train/Raw/32_img_.png
# /kaggle/input/task2subtask1/Train/Raw/120_img_.png
# /kaggle/input/task2subtask1/Train/Raw/776_img_.png
# /kaggle/input/task2subtask1/Train/Raw/303_img_.png
# /kaggle/input/task2subtask1/Train/Raw/560_img_.png
# /kaggle/input/task2subtask1/Train/Raw/657_img_.png
# /kaggle/input/task2subtask1/Train/Raw/780_img_.png
# /kaggle/input/task2subtask1/Train/Raw/391_img_.png
# /kaggle/input/task2subtask1/Train/Raw/557.png
# /kaggle/input/task2subtask1/Train/Raw/811_img_.png
# /kaggle/input/task2subtask1/Train/Raw/444_img_.png
# /kaggle/input/task2subtask1/Train/Raw/124_img_.png
# /kaggle/input/task2subtask1/Train/Raw/721_img_.png
# /kaggle/input/task2subtask1/Train/Raw/7_img_.png
# /kaggle/input/task2subtask1/Train/Raw/447_img_.png
# /kaggle/input/task2subtask1/Train/Raw/550_img_.png
# /kaggle/input/task2subtask1/Train/Raw/813_img_.png
# /kaggle/input/task2subtask1/Train/Raw/504_img_.png
# /kaggle/input/task2subtask1/Train/Raw/778_img_.png
# /kaggle/input/task2subtask1/Train/Raw/571_img_.png
# /kaggle/input/task2subtask1/Train/Raw/845_img_.png
# /kaggle/input/task2subtask1/Train/Raw/1957.png
# /kaggle/input/task2subtask1/Train/Raw/646_img_.png
# /kaggle/input/task2subtask1/Train/Raw/136_img_.png
# /kaggle/input/task2subtask1/Train/Raw/91_img_.png
# /kaggle/input/task2subtask1/Train/Raw/3925.png
# /kaggle/input/task2subtask1/Train/Raw/869_img_.png
# /kaggle/input/task2subtask1/Train/Raw/12900.png
# /kaggle/input/task2subtask1/Train/Raw/607_img_.png
# /kaggle/input/task2subtask1/Train/Raw/740_img_.png
# /kaggle/input/task2subtask1/Train/Raw/720_img_.png
# /kaggle/input/task2subtask1/Train/Raw/313_img_.png
# /kaggle/input/task2subtask1/Train/Raw/419_img_.png
# /kaggle/input/task2subtask1/Train/Raw/9567.png
# /kaggle/input/task2subtask1/Train/Raw/771_img_.png
# /kaggle/input/task2subtask1/Train/Raw/178_img_.png
# /kaggle/input/task2subtask1/Train/Raw/816_img_.png
# /kaggle/input/task2subtask1/Train/Raw/728_img_.png
# /kaggle/input/task2subtask1/Train/Raw/2677.png
# /kaggle/input/task2subtask1/Train/Raw/8010.png
# /kaggle/input/task2subtask1/Train/Raw/698_img_.png
# /kaggle/input/task2subtask1/Train/Raw/60_img_.png
# /kaggle/input/task2subtask1/Train/Raw/555_img_.png
# /kaggle/input/task2subtask1/Train/Raw/11064.png
# /kaggle/input/task2subtask1/Train/Raw/833_img_.png
# /kaggle/input/task2subtask1/Train/Raw/694_img_.png
# /kaggle/input/task2subtask1/Train/Raw/783_img_.png
# /kaggle/input/task2subtask1/Train/Raw/821_img_.png
# /kaggle/input/task2subtask1/Train/Raw/175_img_.png
# /kaggle/input/task2subtask1/Train/Raw/857_img_.png
# /kaggle/input/task2subtask1/Train/Raw/113_img_.png
# /kaggle/input/task2subtask1/Train/Raw/612_img_.png
# /kaggle/input/task2subtask1/Train/Raw/114_img_.png
# /kaggle/input/task2subtask1/Train/Raw/15544.png
# /kaggle/input/task2subtask1/Train/Raw/807_img_.png
# /kaggle/input/task2subtask1/Train/Raw/725_img_.png
# /kaggle/input/task2subtask1/Train/Raw/455_img_.png

# %%
#Importing All Libraries
from IPython import display
import os

import glob
import imageio
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
import cv2

import tensorflow_probability as tfp
import time
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from skimage.metrics import structural_similarity as ssim
import matplotlib.pyplot as plt

# %%
# VAE class definition
class VAE(Model):
    def __init__(self, image_channels):
        super(VAE, self).__init__()
        self.encoder = tf.keras.Sequential([
            layers.Conv2D(8, kernel_size=3, strides=2, padding='same', activation='relu', input_shape=(256, 384, image_channels)),
            layers.Conv2D(16, kernel_size=3, strides=2, padding='same', activation='relu'),
            layers.Flatten()
        ])
        
        self.mu = layers.Dense(128)  # Adjusted latent dimension
        self.logvar = layers.Dense(128)  # Adjusted latent dimension
        
        self.decoder = tf.keras.Sequential([
            layers.Dense(16 * 64 * 96, activation='relu'),  # Adjusted for reshaping
            layers.Reshape((64, 96, 16)),  # Adjusted dimensions
            layers.Conv2DTranspose(16, kernel_size=3, strides=2, padding='same', activation='relu'),
            layers.Conv2DTranspose(8, kernel_size=3, strides=2, padding='same', activation='relu'),
            layers.Conv2DTranspose(image_channels, kernel_size=3, strides=1, padding='same', activation='sigmoid')
        ])
        
    def reparam(self, mu, logvar):
        std = tf.exp(0.5 * logvar)
        eps = tf.random.normal(shape=tf.shape(std))
        return mu + eps * std
    
    def call(self, x):
        x = self.encoder(x)
        
        mu = self.mu(x)
        logvar = self.logvar(x)
        
        z = self.reparam(mu, logvar)
        
        out_image = self.decoder(z)
        return out_image, mu, logvar

# %%
# Define loss function
def loss_f(out, inp, mu, logvar):
    mse = MeanSquaredError()(inp, out)
    kl_div = -0.5 * tf.reduce_mean(1 + logvar - tf.square(mu) - tf.exp(logvar))
    return mse + kl_div

# %%
# Function to load images from a directory
def load_images_from_directory(directory, target_size):
    image_paths = [os.path.join(directory, fname) for fname in os.listdir(directory)]
    images = []
    for image_path in image_paths:
        img = load_img(image_path, target_size=target_size)
        img = img_to_array(img) / 255.0  # Normalize
        images.append(img)
    return np.array(images)

# Load raw and reference images for training
train_raw_path = "/kaggle/input/task2subtask1/Train/Raw"
train_ref_path = "/kaggle/input/task2subtask1/Train/Reference"

train_raw_images = load_images_from_directory(train_raw_path, target_size=(256, 384))
train_ref_images = load_images_from_directory(train_ref_path, target_size=(256, 384))

# Load raw and reference images for testing
test_raw_path = "/kaggle/input/task2subtask1/Test/Raw"
test_ref_path = "/kaggle/input/task2subtask1/Test/Reference"

test_raw_images = load_images_from_directory(test_raw_path, target_size=(256, 384))
test_ref_images = load_images_from_directory(test_ref_path, target_size=(256, 384))

# %%
# Set hyperparameters
image_channels = 3
learning_rate = 1e-3
epochs = 10
batch_size = 1

# Create the model and optimizer
model = VAE(image_channels)
optimizer = Adam(learning_rate)

# %%
for epoch in range(epochs):
    total_loss = 0
    for i in range(len(train_raw_images)):
        with tf.GradientTape() as tape:
            output_img, mu, logvar = model(tf.expand_dims(train_raw_images[i], axis=0))
            loss = loss_f(output_img, tf.expand_dims(train_ref_images[i], axis=0), mu, logvar)
        
        gradients = tape.gradient(loss, model.trainable_variables)
        optimizer.apply_gradients(zip(gradients, model.trainable_variables))
        total_loss += loss.numpy()
    
    print(f'Epoch [{epoch+1}/{epochs}], Loss: {total_loss / len(train_raw_images):.4f}')
# Out:
# Epoch [1/10], Loss: 0.0707
# Epoch [2/10], Loss: 0.0624
# Epoch [3/10], Loss: 0.0611
# Epoch [4/10], Loss: 0.0604
# Epoch [5/10], Loss: 0.0604
# Epoch [6/10], Loss: 0.0603
# Epoch [7/10], Loss: 0.0600
# Epoch [8/10], Loss: 0.0600
# Epoch [9/10], Loss: 0.0598
# Epoch [10/10], Loss: 0.0601

# %%
import numpy as np
import tensorflow as tf
from skimage.metrics import structural_similarity as ssim
from sklearn.metrics import mean_squared_error


# Assume model, test_raw_images, and test_ref_images are already defined

# Save the model weights
model.save_weights("vae1_tf.weights.h5")

# Load the model weights
model.load_weights("vae1_tf.weights.h5")

# Function to calculate SSIM with adaptive window size
def calculate_ssim(img1, img2):
    min_dim = min(img1.shape[0], img1.shape[1])
    
    # Set win_size to the largest possible odd number <= min_dim
    win_size = min_dim if min_dim % 2 != 0 else min_dim - 1
    
    # If win_size is 1, we can't calculate SSIM meaningfully
    if win_size < 3:
        return np.nan
    
    return ssim(img1, img2, win_size=win_size, multichannel=True, data_range=1, channel_axis=-1)

# Function to calculate PSNR
def calculate_psnr(img1, img2):
    mse = mean_squared_error(img1.flatten(), img2.flatten())
    if mse == 0:
        return float('inf')  # Infinite PSNR for identical images
    max_pixel = 1.0  # Assuming the images are normalized between 0 and 1
    return 20 * np.log10(max_pixel / np.sqrt(mse))

# Evaluate on test data
ssim_scores = []
mse_scores = []
psnr_scores = []

for i in range(len(test_raw_images)):
    test_img = tf.expand_dims(test_raw_images[i], axis=0)
    ref_img = test_ref_images[i]
    
    # Run through the model
    reconstructed_img, _, _ = model(test_img)
    
    # Reshape output image
    reconstructed_img = tf.squeeze(reconstructed_img, axis=0).numpy()
    
    # Calculate SSIM with adaptive window size
    ssim_value = calculate_ssim(reconstructed_img, ref_img)
    if not np.isnan(ssim_value):
        ssim_scores.append(ssim_value)
    
    # Calculate MSE
    mse_value = mean_squared_error(ref_img.flatten(), reconstructed_img.flatten())
    mse_scores.append(mse_value)
    
    # Calculate PSNR
    psnr_value = calculate_psnr(ref_img, reconstructed_img)
    psnr_scores.append(psnr_value)

# Calculate average scores across all valid test images
if ssim_scores:
    average_ssim = np.mean(ssim_scores)
    print(f"Average SSIM: {average_ssim:.4f}")
else:
    print("No valid SSIM scores were calculated.")

if mse_scores:
    average_mse = np.mean(mse_scores)
    print(f"Average MSE: {average_mse:.4f}")
else:
    print("No valid MSE scores were calculated.")

if psnr_scores:
    average_psnr = np.mean(psnr_scores)
    print(f"Average PSNR: {average_psnr:.4f} dB")
else:
    print("No valid PSNR scores were calculated.")

# Summary of valid scores
print(f"Number of images used for SSIM calculation: {len(ssim_scores)}")
print(f"Number of images used for MSE calculation: {len(mse_scores)}")
print(f"Number of images used for PSNR calculation: {len(psnr_scores)}")
# Out:
# Average SSIM: 0.1058
# Average MSE: 0.0605
# Average PSNR: 12.4251 dB
# Number of images used for SSIM calculation: 190
# Number of images used for MSE calculation: 190
# Number of images used for PSNR calculation: 190
